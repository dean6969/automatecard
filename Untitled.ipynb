# %%
from PIL import Image, ImageDraw, ImageFont

# %%
data = pd.read_excel("data/DS test.xlsx")

# %%
data
# Out:
#     Stt             Họ và tên  Ngày tháng năm sinh  \
# 0     1     Lê Thị Thùy Dương  1991-08-11 00:00:00
# 1     2     Nguyễn Hiền Lương  1981-09-11 00:00:00
# 2     3         Trần Thu Hằng  1988-11-25 00:00:00
# 3     4           Lê Đình Tâm  1979-10-24 00:00:00
# 4     5               Hà Tùng  1983-01-22 00:00:00
# 5     6        Hoàng Tuấn Anh           01/02/1979
# 6     7          Vũ Công Luân  1984-02-08 00:00:00
# 7     8  Nguyễn Thị Ngọc Phúc  1978-11-03 00:00:00
# 8     9     Nguyễn Thanh Bình  1988-11-01 00:00:00
# 9    10   Tống Thị Hoài Hương  1981-07-04 00:00:00
# 10   11      Nguyễn Văn Quang  1993-05-15 00:00:00
# 11   12     Nguyễn Ngọc Khánh  1993-09-04 00:00:00
# 12   13    Nguyễn Thị Bảo Yến  1993-03-24 00:00:00
# 13   14        Trần Thị Hương  1988-09-24 00:00:00
# 14   15           Ma Thị Mừng  1986-07-28 00:00:00
# 15   16       Nguyễn Anh Quân  1981-12-24 00:00:00
# 16   17        Triệu Ngọc Mão  1987-01-23 00:00:00
# ...

# %%
data.columns
# Out:
# Index(['Stt', 'Họ và tên', 'Ngày tháng năm sinh', 'Vị trí công tác',
#        'Cột mới'],
#       dtype='object')

# %%
records = data.to_dict(orient='record')
def generate_card(data):
    font = ImageFont.truetype("arialbd.ttf", size = 28)
    template = Image.open("VNPAY card.png")
    draw = ImageDraw.Draw(template)
    draw.text((440,245),data['Họ và tên'], font=font, fill = 'black')
    draw.text((490,296),data['Cột mới'], font=font, fill = 'black')
    draw.text((465,348),data['Vị trí công tác'], font=font, fill = 'black')
    return template
for record in records:
    card = generate_card(record)
    card.save("cards/{}.png".format(record['Họ và tên']))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:1549: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   warnings.warn(

# %%
import pandas as pd

data = pd.read_excel("data/data.xlsx")

# %%
data
# Out:
#     Name         date  department
# 0      A1  26/12/1982  Kinh Doanh
# 1      A2  26/12/1983  Kinh Doanh
# 2      A3  26/12/1984  Kinh Doanh
# 3      A4  26/12/1985  Kinh Doanh
# 4      A5  26/12/1986  Kinh Doanh
# ..    ...         ...         ...
# 685  A686  26/12/1995  Kinh Doanh
# 686  A687  26/12/1982  Kinh Doanh
# 687  A688  26/12/1983  Kinh Doanh
# 688  A689  26/12/1984  Kinh Doanh
# 689  A690  26/12/1985  Kinh Doanh
#
# [690 rows x 3 columns]

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:1549: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   warnings.warn(

# %%
records = data.to_dict(orient='record')
def generate_card(data):
    font = ImageFont.truetype("arialbd.ttf", size = 28)
    template = Image.open("VNPAY card.png")
    draw = ImageDraw.Draw(template)
    draw.text((440,245),data['Name '], font=font, fill = 'black')
    draw.text((490,296),data['date'], font=font, fill = 'black')
    draw.text((465,348),data['department'], font=font, fill = 'black')
    return template
for record in records:
    card = generate_card(record)
    card.save("cards/{}.png".format(record['Name ']))
